# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('survey_results_public.csv')
df.head()
# Out:
#    ResponseId     Q120                      MainBranch              Age  \
# 0           1  I agree                   None of these  18-24 years old
# 1           2  I agree  I am a developer by profession  25-34 years old
# 2           3  I agree  I am a developer by profession  45-54 years old
# 3           4  I agree  I am a developer by profession  25-34 years old
# 4           5  I agree  I am a developer by profession  25-34 years old
#
#                                           Employment  \
# 0                                                NaN
# 1                                Employed, full-time
# 2                                Employed, full-time
# 3                                Employed, full-time
# 4  Employed, full-time;Independent contractor, fr...
#
#                              RemoteWork  \
# 0                                   NaN
# 1                                Remote
# 2  Hybrid (some remote, some in-person)
# 3  Hybrid (some remote, some in-person)
# ...

# %%
len(df.columns)
# Out:
# 84

# %%
df.shape
# Out:
# (89184, 84)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89184 entries, 0 to 89183
# Data columns (total 84 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   ResponseId                           89184 non-null  int64
#  1   Q120                                 89184 non-null  object
#  2   MainBranch                           89184 non-null  object
#  3   Age                                  89184 non-null  object
#  4   Employment                           87898 non-null  object
#  5   RemoteWork                           73810 non-null  object
#  6   CodingActivities                     73764 non-null  object
#  7   EdLevel                              87973 non-null  object
#  8   LearnCode                            87663 non-null  object
#  9   LearnCodeOnline                      70084 non-null  object
#  10  LearnCodeCoursesCert                 37076 non-null  object
# ...

# %%
df.describe()
# Out:
#          ResponseId     CompTotal       WorkExp  ConvertedCompYearly
# count  89184.000000  4.822500e+04  43579.000000         4.801900e+04
# mean   44592.500000  1.036807e+42     11.405126         1.031101e+05
# std    25745.347541  2.276847e+44      9.051989         6.814188e+05
# min        1.000000  0.000000e+00      0.000000         1.000000e+00
# 25%    22296.750000  6.300000e+04      5.000000         4.390700e+04
# 50%    44592.500000  1.150000e+05      9.000000         7.496300e+04
# 75%    66888.250000  2.300000e+05     16.000000         1.216410e+05
# max    89184.000000  5.000000e+46     50.000000         7.435143e+07

# %%
df.columns
# Out:
# Index(['ResponseId', 'Q120', 'MainBranch', 'Age', 'Employment', 'RemoteWork',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        'LearnCodeCoursesCert', 'YearsCode', 'YearsCodePro', 'DevType',
#        'OrgSize', 'PurchaseInfluence', 'TechList', 'BuyNewTool', 'Country',
#        'Currency', 'CompTotal', 'LanguageHaveWorkedWith',
#        'LanguageWantToWorkWith', 'DatabaseHaveWorkedWith',
#        'DatabaseWantToWorkWith', 'PlatformHaveWorkedWith',
#        'PlatformWantToWorkWith', 'WebframeHaveWorkedWith',
#        'WebframeWantToWorkWith', 'MiscTechHaveWorkedWith',
#        'MiscTechWantToWorkWith', 'ToolsTechHaveWorkedWith',
#        'ToolsTechWantToWorkWith', 'NEWCollabToolsHaveWorkedWith',
#        'NEWCollabToolsWantToWorkWith', 'OpSysPersonal use',
#        'OpSysProfessional use', 'OfficeStackAsyncHaveWorkedWith',
#        'OfficeStackAsyncWantToWorkWith', 'OfficeStackSyncHaveWorkedWith',
# ...

# %%
df.isnull().sum()
# Out:
# ResponseId                 0
# Q120                       0
# MainBranch                 0
# Age                        0
# Employment              1286
#                        ...
# ProfessionalTech       47401
# Industry               52410
# SurveyLength            2699
# SurveyEase              2630
# ConvertedCompYearly    41165
# Length: 84, dtype: int64

# %% [markdown]
# * <B>categorical - Q120, MainBranch, Age, Employment, CodingActivities, EdLevel, LearnCode, YearsCode, LanguageHaveWorkedWith,DatabaseHaveWorkedWith, DevType,  Frequency_1, Frequency_2, Frequency_3, WorkExp, Industry, SurveyLength, SurveyEase, Country</B>

# %% [markdown]
# # Univariate Analysis

# %%
df['Q120'].value_counts()
# Out:
# I agree    89184
# Name: Q120, dtype: int64

# %% [markdown]
# <B>MainBranch</B>

# %%
df['MainBranch'].value_counts()
# Out:
# I am a developer by profession                                                           67237
# I am not primarily a developer, but I write code sometimes as part of my work/studies     8954
# I am learning to code                                                                     4961
# I code primarily as a hobby                                                               4960
# I used to be a developer by profession, but no longer am                                  1861
# None of these                                                                             1211
# Name: MainBranch, dtype: int64

# %%
(df['MainBranch'].value_counts(normalize=True)) * 100
# Out:
# I am a developer by profession                                                           75.391326
# I am not primarily a developer, but I write code sometimes as part of my work/studies    10.039917
# I am learning to code                                                                     5.562657
# I code primarily as a hobby                                                               5.561536
# I used to be a developer by profession, but no longer am                                  2.086697
# None of these                                                                             1.357867
# Name: MainBranch, dtype: float64

# %%
df['MainBranch'].value_counts().plot(kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: ylabel='MainBranch'>

# %% [markdown]
# <B> Age </B>

# %%
df['Age'].value_counts()
# Out:
# 25-34 years old       33247
# 35-44 years old       20532
# 18-24 years old       17931
# 45-54 years old        8334
# Under 18 years old     4128
# 55-64 years old        3392
# 65 years or older      1171
# Prefer not to say       449
# Name: Age, dtype: int64

# %%
df['Age'].value_counts(normalize=True) * 100
# Out:
# 25-34 years old       37.279108
# 35-44 years old       23.022067
# 18-24 years old       20.105624
# 45-54 years old        9.344726
# Under 18 years old     4.628633
# 55-64 years old        3.803373
# 65 years or older      1.313016
# Prefer not to say      0.503454
# Name: Age, dtype: float64

# %%
df['Age'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# <B> Employment </B>

# %%
len(df['Employment'].unique())
# Out:
# 107

# %%
df['Employment'].value_counts().nlargest(5)
# Out:
# Employed, full-time                                                         53748
# Student, full-time                                                           7430
# Independent contractor, freelancer, or self-employed                         7076
# Employed, full-time;Independent contractor, freelancer, or self-employed     4354
# Not employed, but looking for work                                           2553
# Name: Employment, dtype: int64

# %%
df['Employment'].value_counts(normalize=True).nlargest(5).plot(kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: ylabel='Employment'>

# %% [markdown]
# <B>CodingActivities</B>

# %%
df['CodingActivities'].value_counts()
# Out:
# Hobby                                                                                                                                                                                    15308
# I don’t code outside of work                                                                                                                                                              8809
# Hobby;Professional development or self-paced learning from online courses                                                                                                                 8232
# Hobby;Contribute to open-source projects                                                                                                                                                  5363
# Professional development or self-paced learning from online courses                                                                                                                       3920
# ...

# %%
df['CodingActivities'].value_counts().nlargest(5)
# Out:
# Hobby                                                                        15308
# I don’t code outside of work                                                  8809
# Hobby;Professional development or self-paced learning from online courses     8232
# Hobby;Contribute to open-source projects                                      5363
# Professional development or self-paced learning from online courses           3920
# Name: CodingActivities, dtype: int64

# %%
df['CodingActivities'].value_counts().nlargest(5).plot(kind='pie',autopct='%0.1f%%',label=' ')
# Out:
# <Axes: ylabel=' '>

# %% [markdown]
# <B> EdLevel </B>

# %%
df['EdLevel'].value_counts()
# Out:
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                          36706
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                       20543
# Some college/university study without earning a degree                                11753
# Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)     8897
# Professional degree (JD, MD, Ph.D, Ed.D, etc.)                                         3887
# Associate degree (A.A., A.S., etc.)                                                    2807
# Primary/elementary school                                                              1905
# Something else                                                                         1475
# Name: EdLevel, dtype: int64

# %%
(df['EdLevel'].value_counts(normalize=True).nlargest(5)) * 100
# Out:
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                          41.724165
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                       23.351483
# Some college/university study without earning a degree                                13.359781
# Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)    10.113330
# Professional degree (JD, MD, Ph.D, Ed.D, etc.)                                         4.418401
# Name: EdLevel, dtype: float64

# %%
df['EdLevel'].value_counts(normalize=True).nlargest(5).plot(kind='pie',autopct='%0.1f%%',label=' ')
# Out:
# <Axes: ylabel=' '>

# %% [markdown]
# <B>LearnCode</B>

# %%
len(df['LearnCode'].unique())
# Out:
# 791

# %%
df['LearnCode'].value_counts()
# Out:
# Other online resources (e.g., videos, blogs, forum)                                                                                                                                                             4873
# Books / Physical media;Other online resources (e.g., videos, blogs, forum)                                                                                                                                      3300
# Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc)                                                                                                                     3070
# Books / Physical media;Online Courses or Certification;Other online resources (e.g., videos, blogs, forum)                                                                                                      3024
# ...

# %%
df['LearnCode'].isnull().sum()
# Out:
# 1521

# %%
(df['LearnCode'].value_counts(normalize=True).nlargest(5)) * 100
# Out:
# Other online resources (e.g., videos, blogs, forum)                                                           5.558788
# Books / Physical media;Other online resources (e.g., videos, blogs, forum)                                    3.764416
# Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc)                   3.502048
# Books / Physical media;Online Courses or Certification;Other online resources (e.g., videos, blogs, forum)    3.449574
# Online Courses or Certification;Other online resources (e.g., videos, blogs, forum)                           3.275042
# Name: LearnCode, dtype: float64

# %%
df['LearnCode'].value_counts(normalize=True).nlargest(5).plot(kind='pie',autopct='%0.1f%%',label=' ')
# Out:
# <Axes: ylabel=' '>

# %% [markdown]
# <B> YearsCode </B>

# %%
len(df['YearsCode'].unique())
# Out:
# 53

# %%
df['YearsCode'].value_counts()
# Out:
# 10                    6521
# 5                     5415
# 6                     4893
# 8                     4879
# 7                     4800
# 4                     4466
# 15                    4336
# 3                     4269
# 20                    4021
# 12                    3471
# 9                     3130
# 2                     2826
# 25                    2685
# 13                    2601
# 11                    2519
# 14                    2278
# 30                    2078
# 16                    1842
# 18                    1690
# 17                    1544
# 23                    1327
# 40                    1302
# 1                     1294
# 22                    1210
# 35                    1118
# Less than 1 year       968
# 24                     959
# 19                     826
# 21                     761
# 28                     715
# 27                     710
# 26                     706
# 33                     496
# 32                     444
# ...

# %%
df['YearsCode'].value_counts().nlargest(10).plot(kind='bar',figsize=(10,8))
# Out:
# <Axes: >

# %% [markdown]
# <B> LanguageHaveWorkedWith </B>

# %%
df['LanguageHaveWorkedWith'].value_counts().nlargest(10)
# Out:
# HTML/CSS;JavaScript;TypeScript           1487
# Python                                   1132
# HTML/CSS;JavaScript                       735
# HTML/CSS;JavaScript;PHP;SQL               718
# C#                                        649
# JavaScript;TypeScript                     590
# C#;HTML/CSS;JavaScript;SQL;TypeScript     575
# Java                                      573
# Python;SQL                                460
# C#;HTML/CSS;JavaScript;SQL                449
# Name: LanguageHaveWorkedWith, dtype: int64

# %%
(df['LanguageHaveWorkedWith'].value_counts(normalize=True).nlargest(10)) * 100
# Out:
# HTML/CSS;JavaScript;TypeScript           1.706449
# Python                                   1.299059
# HTML/CSS;JavaScript                      0.843470
# HTML/CSS;JavaScript;PHP;SQL              0.823961
# C#                                       0.744779
# JavaScript;TypeScript                    0.677071
# C#;HTML/CSS;JavaScript;SQL;TypeScript    0.659858
# Java                                     0.657563
# Python;SQL                               0.527886
# C#;HTML/CSS;JavaScript;SQL               0.515263
# Name: LanguageHaveWorkedWith, dtype: float64

# %%
df['LanguageHaveWorkedWith'].value_counts().nlargest(10).plot(kind='bar',figsize=(10,8))
# Out:
# <Axes: >

# %% [markdown]
# <B> LanguageWantToWorkWith</B>

# %%
df['LanguageWantToWorkWith'].value_counts().nlargest(10)
# Out:
# Rust                              1438
# Python                            1182
# HTML/CSS;JavaScript;TypeScript    1071
# C#                                 736
# Go                                 618
# TypeScript                         493
# JavaScript;TypeScript              451
# Java                               450
# Python;Rust                        446
# Python;SQL                         424
# Name: LanguageWantToWorkWith, dtype: int64

# %%
df['LanguageWantToWorkWith'].value_counts(normalize=True).nlargest(10).plot(kind='pie',autopct='%0.1f%%',label=' ')
# Out:
# <Axes: ylabel=' '>

# %% [markdown]
# <B> DatabaseHaveWorkedWith </B>

# %%
df['DatabaseHaveWorkedWith'].value_counts().nlargest(10)
# Out:
# PostgreSQL              4350
# Microsoft SQL Server    3322
# MySQL                   3116
# SQLite                  2299
# MongoDB                 1663
# PostgreSQL;SQLite       1426
# PostgreSQL;Redis        1024
# MariaDB;MySQL           1001
# MySQL;SQLite             969
# MySQL;PostgreSQL         945
# Name: DatabaseHaveWorkedWith, dtype: int64

# %%
(df['DatabaseHaveWorkedWith'].value_counts(normalize=True).nlargest(10)) * 100
# Out:
# PostgreSQL              5.923606
# Microsoft SQL Server    4.523728
# MySQL                   4.243208
# SQLite                  3.130660
# MongoDB                 2.264588
# PostgreSQL;SQLite       1.941853
# PostgreSQL;Redis        1.394430
# MariaDB;MySQL           1.363110
# MySQL;SQLite            1.319534
# MySQL;PostgreSQL        1.286852
# Name: DatabaseHaveWorkedWith, dtype: float64

# %%
df['DatabaseHaveWorkedWith'].value_counts().nlargest(10).plot(kind='bar')
# Out:
# <Axes: >

# %%
df['DatabaseHaveWorkedWith'].isnull().sum()
# Out:
# 15749

# %% [markdown]
# <B> DatabaseWantToWorkWith </B>

# %%
df['DatabaseWantToWorkWith'].value_counts().nlargest(10)
# Out:
# PostgreSQL                 4815
# Microsoft SQL Server       2180
# SQLite                     1771
# MySQL                      1754
# PostgreSQL;SQLite          1631
# MongoDB                    1609
# PostgreSQL;Redis           1414
# MongoDB;PostgreSQL          772
# MySQL;PostgreSQL            625
# PostgreSQL;Redis;SQLite     582
# Name: DatabaseWantToWorkWith, dtype: int64

# %%
(df['DatabaseWantToWorkWith'].value_counts(normalize=True).nlargest(10)) * 100
# Out:
# PostgreSQL                 7.904976
# Microsoft SQL Server       3.578992
# SQLite                     2.907521
# MySQL                      2.879611
# PostgreSQL;SQLite          2.677677
# MongoDB                    2.641559
# PostgreSQL;Redis           2.321420
# MongoDB;PostgreSQL         1.267423
# MySQL;PostgreSQL           1.026087
# PostgreSQL;Redis;SQLite    0.955492
# Name: DatabaseWantToWorkWith, dtype: float64

# %%
df['DatabaseWantToWorkWith'].value_counts().nlargest(10).plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# <B> DevType </B>

# %%
df['DevType'].value_counts().nlargest(10)
# Out:
# Developer, full-stack                            25735
# Developer, back-end                              13745
# Developer, front-end                              5071
# Developer, desktop or enterprise applications     3904
# Other (please specify):                           3080
# Developer, mobile                                 2597
# Engineering manager                               2033
# Student                                           1996
# Developer, embedded applications or devices       1845
# Data scientist or machine learning specialist     1588
# Name: DevType, dtype: int64

# %%
df['DevType'].value_counts().nlargest(10).plot(kind='pie',autopct='%0.1f%%',label=' ')
# Out:
# <Axes: ylabel=' '>

# %% [markdown]
# <B>Freuency_1</B>

# %%
df['Frequency_1'].value_counts().nlargest(5)
# Out:
# 1-2 times a week     25528
# Never                10707
# 3-5 times a week      4100
# 6-10 times a week      847
# 10+ times a week       734
# Name: Frequency_1, dtype: int64

# %%
(df['Frequency_1'].value_counts(normalize=True).nlargest(5))*100
# Out:
# 1-2 times a week     60.902758
# Never                25.543945
# 3-5 times a week      9.781468
# 6-10 times a week     2.020708
# 10+ times a week      1.751121
# Name: Frequency_1, dtype: float64

# %%
df['Frequency_1'].value_counts().nlargest(5).plot(kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: ylabel='Frequency_1'>

# %%
df['WorkExp'].value_counts().nlargest(5)
# Out:
# 5.0     3299
# 10.0    3019
# 2.0     2796
# 3.0     2781
# 4.0     2529
# Name: WorkExp, dtype: int64

# %%
df['WorkExp'].value_counts(normalize=True).nlargest(5).plot(kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: ylabel='WorkExp'>

# %%
df['Industry'].value_counts().nlargest(5)
# Out:
# Information Services, IT, Software Development, or other Technology    18159
# Financial Services                                                      4421
# Other                                                                   4011
# Manufacturing, Transportation, or Supply Chain                          2607
# Healthcare                                                              2216
# Name: Industry, dtype: int64

# %%
df['Industry'].value_counts().nlargest(5).plot(kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: ylabel='Industry'>

# %%
df['SurveyLength'].value_counts()
# Out:
# Appropriate in length    65962
# Too long                 18605
# Too short                 1918
# Name: SurveyLength, dtype: int64

# %%
df['SurveyLength'].value_counts(normalize=True).plot(kind='pie',autopct='%0.1f%%',label=' ')
# Out:
# <Axes: ylabel=' '>

# %%
df['SurveyEase'].value_counts()
# Out:
# Easy                          54092
# Neither easy nor difficult    31088
# Difficult                      1374
# Name: SurveyEase, dtype: int64

# %%
df['SurveyEase'].value_counts(normalize=True).plot(kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: ylabel='SurveyEase'>

# %%
df['Country'].value_counts()
# Out:
# United States of America                                18647
# Germany                                                  7328
# India                                                    5625
# United Kingdom of Great Britain and Northern Ireland     5552
# Canada                                                   3507
#                                                         ...
# Saint Kitts and Nevis                                       1
# Marshall Islands                                            1
# Samoa                                                       1
# Central African Republic                                    1
# San Marino                                                  1
# Name: Country, Length: 185, dtype: int64

# %%
df['Country'].value_counts().nlargest(5)
# Out:
# United States of America                                18647
# Germany                                                  7328
# India                                                    5625
# United Kingdom of Great Britain and Northern Ireland     5552
# Canada                                                   3507
# Name: Country, dtype: int64

# %%
df['Country'].value_counts(normalize=True).nlargest(5).plot(kind='pie',autopct='%0.1f%%',label=' ')
# Out:
# <Axes: ylabel=' '>

# %% [markdown]
# # Bivariate analysis

# %%
df.columns
# Out:
# Index(['ResponseId', 'Q120', 'MainBranch', 'Age', 'Employment', 'RemoteWork',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        'LearnCodeCoursesCert', 'YearsCode', 'YearsCodePro', 'DevType',
#        'OrgSize', 'PurchaseInfluence', 'TechList', 'BuyNewTool', 'Country',
#        'Currency', 'CompTotal', 'LanguageHaveWorkedWith',
#        'LanguageWantToWorkWith', 'DatabaseHaveWorkedWith',
#        'DatabaseWantToWorkWith', 'PlatformHaveWorkedWith',
#        'PlatformWantToWorkWith', 'WebframeHaveWorkedWith',
#        'WebframeWantToWorkWith', 'MiscTechHaveWorkedWith',
#        'MiscTechWantToWorkWith', 'ToolsTechHaveWorkedWith',
#        'ToolsTechWantToWorkWith', 'NEWCollabToolsHaveWorkedWith',
#        'NEWCollabToolsWantToWorkWith', 'OpSysPersonal use',
#        'OpSysProfessional use', 'OfficeStackAsyncHaveWorkedWith',
#        'OfficeStackAsyncWantToWorkWith', 'OfficeStackSyncHaveWorkedWith',
# ...

# %%
df.groupby('Employment')['Age'].value_counts()
# Out:
# Employment                                                 Age
# Employed, full-time                                        25-34 years old      24375
#                                                            35-44 years old      15109
#                                                            18-24 years old       5923
#                                                            45-54 years old       5816
#                                                            55-64 years old       2073
#                                                                                 ...
# Student, part-time;Not employed, and not looking for work  18-24 years old         19
#                                                            25-34 years old          5
#                                                            Prefer not to say        3
#                                                            35-44 years old          1
# ...

# %%
df.groupby('Age')['Employment'].value_counts().nlargest(3).plot(kind='bar')
# Out:
# <Axes: xlabel='Age,Employment'>
